# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajadharsini2004/technohacks-tasks/blob/main/house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
file_path = '/content/house price prediction.csv'
df = pd.read_csv(file_path)
print(df.head(10))
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1230000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.scatter(df['price'], df['grade'])
plt.title('Scatter Plot of price vs grade')
plt.xlabel('price')
plt.ylabel('Grade')
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.violinplot(x='floors', y='price', data=df)
plt.title(' price of a house based on floors')
plt.xlabel('price')
plt.ylabel('floors')
plt.show()

# %%
plt.plot(df['yr_built'], df['sqft_living'])
plt.title('Line Plot ')
plt.xlabel('year of built')
plt.ylabel('sqft living')
plt.show()

# %%
pip install scikit-learn

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

print("\nNormalized DataFrame:")
print(df)
# Out:
# Normalized DataFrame:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  0.019266  0.090909    0.12500     0.067170
# 6414100192  20141209T000000  0.060721  0.090909    0.28125     0.172075
# 5631500400  20150225T000000  0.013770  0.060606    0.12500     0.036226
# 2487200875  20141209T000000  0.069377  0.121212    0.37500     0.126038
# 1954400510  20150218T000000  0.057049  0.090909    0.25000     0.104906
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  0.037377  0.090909    0.31250     0.093585
# 6600060120  20150223T000000  0.042623  0.121212    0.31250     0.152453
# 1523300141  20140623T000000  0.042898  0.060606    0.09375     0.055094
# 291310100   20150116T000000  0.042623  0.090909    0.31250     0.098868
# 1523300157  20141015T000000  0.032787  0.060606    0.09375     0.055094
#
#             sqft_lot  floors  waterfront  view  condition     grade  \
# id
# ...

# %%
pip install pandas numpy matplotlib scipy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
column_of_interest = 'sqft_lot'
data = df[column_of_interest]

plt.hist(data, bins=30, density=True, alpha=0.5, color='b')

mean, std_dev = norm.fit(data)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)
plt.plot(x, p, 'k', linewidth=2)

title = f"Fit results: mean = {mean:.2f},  std = {std_dev:.2f}"
plt.title(title)

plt.show()

# %%
pip install pandas numpy matplotlib

# %%
plt.bar(df['grade'], df['price'])
plt.title('Bar Plot of Categories')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
plt.boxplot(df['yr_built'])
plt.title('Box Plot')
plt.ylabel('year of built')

plt.show()
